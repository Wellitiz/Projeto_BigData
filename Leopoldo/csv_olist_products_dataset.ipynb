# %% [markdown]
# PRODUCTS DATASET

# %% [markdown]
#  --- Dataset composto por 32951 linhas e 9 colunas

# %%
import pandas as pd 
import numpy as np


dts = pd.read_csv("C:/Users/leopo/OneDrive/Documentos/KORU IFOOD POTENCIA TECH/MOD3 BIG DATA PYTHON E PYSPARK/download_datasets/brazilian-ecommerce/olist_products_dataset.csv")

# %%
dts
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
dts.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
dts.shape
# Out:
# (32951, 9)

# %%
dts.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %% [markdown]
# A coluna PRODUCT_CATEGORY_NAME é composta por valores em lowercase sem caracteres especiais e os espaços estão preenchidos por underscore.

# %%
dts[['product_category_name']]
# Out:
#                    product_category_name
# 0                             perfumaria
# 1                                  artes
# 2                          esporte_lazer
# 3                                  bebes
# 4                  utilidades_domesticas
# ...                                  ...
# 32946                   moveis_decoracao
# 32947  construcao_ferramentas_iluminacao
# 32948                    cama_mesa_banho
# 32949             informatica_acessorios
# 32950                    cama_mesa_banho
#
# [32951 rows x 1 columns]

# %%
dts[['product_category_name']].count()
# Out:
# product_category_name    32341
# dtype: int64

# %%
dts.isna()
# Out:
#        product_id  product_category_name  product_name_lenght  \
# 0           False                  False                False
# 1           False                  False                False
# 2           False                  False                False
# 3           False                  False                False
# 4           False                  False                False
# ...           ...                    ...                  ...
# 32946       False                  False                False
# 32947       False                  False                False
# 32948       False                  False                False
# 32949       False                  False                False
# 32950       False                  False                False
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           False               False             False
# 1                           False               False             False
# ...

# %%
dts.isnull()
# Out:
#        product_id  product_category_name  product_name_lenght  \
# 0           False                  False                False
# 1           False                  False                False
# 2           False                  False                False
# 3           False                  False                False
# 4           False                  False                False
# ...           ...                    ...                  ...
# 32946       False                  False                False
# 32947       False                  False                False
# 32948       False                  False                False
# 32949       False                  False                False
# 32950       False                  False                False
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           False               False             False
# 1                           False               False             False
# ...
