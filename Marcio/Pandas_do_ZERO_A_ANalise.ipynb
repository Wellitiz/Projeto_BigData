# %% [markdown]
# <a href="https://colab.research.google.com/github/Wellitiz/Projeto_BigData/blob/main/Pandas_do_ZERO_A_ANalise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 03
# ##Extraindo Dados
# ###Via Python

# %%
tabela1.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8e20fb61fe52> in <cell line: 1>()
# ----> 1 tabela1.read()
#
# NameError: name 'tabela1' is not defined

# %%
# !pip install pandas
from datetime import datetime

# %% [markdown]
# ###Versão do Pandas

# %%
import pandas
pandas.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## convenção de importação

# %%
import pandas as pd

# %% [markdown]
# #CIDADE DO CLIENTE / ESTADO DO CLIENTE

# %%
tabela1=pd.read_csv("/content/olist_customers_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-80cd1559c8c4> in <cell line: 1>()
# ----> 1 tabela1=pd.read_csv("/content/olist_customers_dataset.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
tabela1=open("/content/olist_customers_dataset.csv")
tabela1.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-7abdfdf2cfe3> in <cell line: 1>()
# ----> 1 tabela1=open("/content/olist_customers_dataset.csv")
#       2 tabela1.readlines()
#       3
#       4
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/olist_customers_dataset.csv'

# %% [markdown]
# #GEOLOCALIZAÇÃO CIDADE/ESTADO

# %%
tabela2=pd.read_csv("/content/olist_geolocation_dataset.csv")
tabela2.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-b85ca90561b7> in <cell line: 1>()
# ----> 1 tabela2=pd.read_csv("/content/olist_geolocation_dataset.csv")
#       2 tabela2.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# #PREÇO

# %%
tabela3=pd.read_csv("/content/olist_order_items_dataset.csv")
tabela3
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# #PAGAMENTO E VALOR DO PAGAMENTO

# %%
tabela4=pd.read_csv("/content/olist_order_payments_dataset.csv")
tabela4.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %% [markdown]
# #AVALIAÇÃO

# %%
tabela5=pd.read_csv("https://raw.githubusercontent.com/Wellitiz/Projeto_BigData/main/dataset/olist_order_reviews_dataset.csv")
tabela5["review_comment_title"[:99224]]

tabela5
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
from datetime import datetime

tabela_avaliacao=tabela5.groupby("review_creation_date")[["review_creation_date","review_answer_timestamp"]].count()
tabela_avaliacao['dias_para_resolver'] = tabela_avaliacao
display(tabela_avaliacao)

# %%
tabela_avaliacao = tabela5.groupby("diferenca").mean()
print(tabela_avaliacao)

# %%
dias_para_resolver=tabela5['dias_para_resolver'] = tabela5= ['review_creation_date'] - tabela_avaliacao['review_answer_timestamp']

display(tabela5)

# %%
import pandas as pd
from datetime import datetime
tabela_avaliacao=pd.read_csv("https://raw.githubusercontent.com/Wellitiz/Projeto_BigData/main/dataset/olist_order_reviews_dataset.csv")

display(tabela_avaliacao)
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
import pandas as pd

# Ler o DataFrame
tabela_avaliacao = pd.read_csv("https://raw.githubusercontent.com/Wellitiz/Projeto_BigData/main/dataset/olist_order_reviews_dataset.csv")

# Converter as colunas de datas para objetos datetime
#tabela_avaliacao['review_answer_timestamp'] = pd.to_datetime(tabela_avaliacao['review_answer_timestamp'])
#tabela_avaliacao['review_creation_date'] = pd.to_datetime(tabela_avaliacao['review_creation_date'])
#print("tabela_avaliacao")
# Calcular a diferença em dias e criar uma nova coluna 'dias_para_resolver'
tabela_avaliacao['dias_para_resolver'] = (tabela_avaliacao['review_answer_timestamp'] - tabela_avaliacao['review_creation_date']).dt.days
print("tabela_avaliacao")

# Exibir o resultado
#display(tabela_avaliacao)

# Corrigir o agrupamento e calcular a média
tabela_agrupada = tabela_avaliacao.groupby("dias_para_resolver").agg({
    "review_creation_date": 'count',
    "review_answer_timestamp": 'count'
}).mean()
display(tabela_avaliacao)

# Renomear as colunas
#tabela_agrupada.rename(columns={
 #   'review_creation_date': 'quantidade_avaliacoes',
  #  'review_answer_timestamp': 'quantidade_resolvidas'
#}, inplace=True)

# Calcular a média
tabela_agrupada["tabela_avaliacao"] = tabela_agrupada["tabela_avaliacao"] * tabela_agrupada["review_creation_dat"] - tabela_agrupada["review_answer_timestamp"]
display(tabela_agrupada)
# Exibir o resultado
#display(tabela_agrupada[['dias_para_resolver', 'media_dias_para_resolver']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
tabela6=pd.read_csv("/content/olist_orders_dataset.csv")
display(tabela6)
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# #CATEGORIA DO PRODUTO (EX: PERFUMARIA, LIVROS, CAMA MESA E BANHO)

# %%
tabela7=pd.read_csv("/content/olist_products_dataset.csv")
tabela7.values
# Out:
# array([['1e9e8ef04dbcff4541ed26657ea517e5', 'perfumaria', 40.0, ...,
#         16.0, 10.0, 14.0],
#        ['3aa071139cb16b67ca9e5dea641aaa2f', 'artes', 44.0, ..., 30.0,
#         18.0, 20.0],
#        ['96bd76ec8810374ed1b65e291975717f', 'esporte_lazer', 46.0, ...,
#         18.0, 9.0, 15.0],
#        ...,
#        ['9a7c6041fa9592d9d9ef6cfe62a71f8c', 'cama_mesa_banho', 50.0, ...,
#         27.0, 7.0, 27.0],
#        ['83808703fc0706a22e264b9d75f04a2e', 'informatica_acessorios',
#         60.0, ..., 31.0, 13.0, 20.0],
#        ['106392145fca363410d287a815be6de4', 'cama_mesa_banho', 58.0, ...,
#         12.0, 2.0, 7.0]], dtype=object)

# %% [markdown]
# #CIDADE/ESTADO DO VENDEDOR

# %%
tabela8=pd.read_csv("/content/olist_sellers_dataset.csv")
display(tabela8)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
tabela_cidades=tabela8.groupby("seller_state")["seller_id"]
display(tabela_cidades)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7dcc7552dc10> in <cell line: 1>()
# ----> 1 tabela_cidades=tabela8.groupby("seller_state")["seller_id"]
#       2 display(tabela_cidades)
#
# NameError: name 'tabela8' is not defined

# %% [markdown]
# #CATEGORIA EM PORTUGUE E CATEGORIA EM INGLÊS

# %%
tabela9=pd.read_csv("/content/product_category_name_translation.csv")
display(tabela9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00e053e1db74> in <cell line: 1>()
# ----> 1 tabela9=pd.read_csv("/content/product_category_name_translation.csv")
#       2 display(tabela9)
#
# NameError: name 'pd' is not defined

# %%
tabela9['product_category_name'[0:72]].value_counts(normalize=True)

# %%
tabela.loc[0:10,["product_name_lenght","product_category_name",]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8d49e9e7406> in <cell line: 1>()
# ----> 1 tabela.loc[0:10,["product_name_lenght","product_category_name",]]
#
# NameError: name 'tabela' is not defined

# %%
tabela.iloc[5:10,1:3]
# Out:
#    product_category_name  product_name_lenght
# 5  instrumentos_musicais                 60.0
# 6             cool_stuff                 56.0
# 7       moveis_decoracao                 56.0
# 8       eletrodomesticos                 57.0
# 9             brinquedos                 36.0

# %%
tabela[tabela["product_name_lenght"]>60]
# Out:
#                              product_id  product_category_name  \
# 40     8b3a9476f74f5297f7ff0ec6d95fe1ea       moveis_decoracao
# 118    7f6308ba4057a6a740af7b4dcfb79c13              telefonia
# 196    68bfdbfe84f03af17733b10362f10020       moveis_decoracao
# 256    302a19dacdbb5ed2f74f9dee8126ef79                  bebes
# 324    8d51190d4e52d32e6abf3d0551501114              telefonia
# ...                                 ...                    ...
# 32761  b906473f6ad88809cd95a1e7e77cd91f  instrumentos_musicais
# 32859  daf9915404caf75fa1717a436b46fa14       moveis_decoracao
# 32872  90467a0531183f8fd2cc76ca735df8a5       moveis_decoracao
# 32941  6ec96c91757fad0aecafc0ee7f262dcc                  bebes
# 32942  16280ca280a86fee2ba3c928ed04439f       moveis_decoracao
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 40                    63.0                       254.0                 2.0
# ...

# %%
tabela['product_category_name'].value_counts(normalize=True)
# Out:
# cama_mesa_banho                  0.093658
# esporte_lazer                    0.088649
# moveis_decoracao                 0.082156
# beleza_saude                     0.075570
# utilidades_domesticas            0.072199
#                                    ...
# fashion_roupa_infanto_juvenil    0.000155
# casa_conforto_2                  0.000155
# pc_gamer                         0.000093
# seguros_e_servicos               0.000062
# cds_dvds_musicais                0.000031
# Name: product_category_name, Length: 73, dtype: float64

# %%
tabela[["product_length_cm","product_height_cm"]].apply(lambda x:x.sum())
# Out:
# product_length_cm    1015326.0
# product_height_cm     558079.0
# dtype: float64

# %%
tabela[["product_category_name"]].value_counts().plot(kind="bar")

# %% [markdown]
# \#MERGE(união de dois DATASETS diferentes

# %%
tabela10=pd.merge([tabela1,tabela2]).sum()

display(tabela10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-48d707ed9c36> in <cell line: 1>()
# ----> 1 tabela10=pd.merge([tabela1,tabela2]).sum()
#       2
#       3 display(tabela10)
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
tabela1.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %% [markdown]
# #Tabela forma de pagamento (payment_type
# ##Foi abaixado o arquivo com os dados com a tabela forma de pagamento

# %%
forma_pagamento=pd.read_csv("https://raw.githubusercontent.com/Wellitiz/Projeto_BigData/main/dataset/olist_order_payments_dataset.csv")
display(forma_pagamento)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# TIPO DE PAGAMENTO :
# QUAL A MEDIA DE VEZES QUE AS COMPRAR FORAM PARCELADAS USANDO O CARTÃO DE CREDITO

# %%
 = items_df.groupby("payment_type").agg({
    "payment_installments": 'mean'
}).round(0).astype(int).reset_index()

# Exibir o resultado
display(items_total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-aa0e71ea8ade> in <cell line: 1>()
# ----> 1 items_total = items_df.groupby("payment_type").agg({
#       2     "payment_installments": 'mean'
#       3 }).round(0).astype(int).reset_index()
#       4
#       5 # Exibir o resultado
#
# NameError: name 'items_df' is not defined

# %%
tabela

# %%
tabela11=pd.read_csv("https://raw.githubusercontent.com/Wellitiz/Projeto_BigData/main/dataset/olist_customers_dataset.csv")
display(tabela11)

display(tabela1)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...
