# %%
import pandas as pd

# %%
orders = pd.read_csv('t_olist_orders_dataset.csv')
order_items = pd.read_csv('csv_olist_order_items_dataset.csv')
products = pd.read_csv('olist_products_dataset.csv')

# %%
merged_data = pd.merge(orders, order_items, on='order_id', how='inner')
merged_data = pd.merge(merged_data, products, on='product_id', how='inner')

# %%
display(merged_data.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 2  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 3  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 4  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp_date order_purchase_timestamp_hour  \
# 0    delivered                    2017-10-02                      10:56:33
# 1    delivered                    2017-08-15                      18:29:31
# 2    delivered                    2017-08-02                      18:24:47
# 3    delivered                    2017-10-23                      23:26:46
# 4    delivered                    2018-07-24                      20:41:37
#
#   order_approved_at_date order_approved_at_hour  \
# 0             2017-10-02               11:07:15
# 1             2017-08-15               20:05:16
# 2             2017-08-02               18:43:15
# 3             2017-10-25               02:14:11
# 4             2018-07-26               03:24:27
#
#   order_delivered_carrier_date_date order_delivered_carrier_date_hour  \
# 0                        2017-10-04                          19:55:00
# 1                        2017-08-17                          15:28:33
# 2                        2017-08-04                          17:35:43
# 3                        2017-10-27                          16:48:46
# 4                        2018-07-26                          14:31:00
#
#   order_delivered_customer_date_date  ...     date_id   time_id  \
# 0                         2017-10-10  ...  2017-10-06  11:07:15
# 1                         2017-08-18  ...  2017-08-21  20:05:16
# 2                         2017-08-07  ...  2017-08-08  18:37:31
# 3                         2017-11-07  ...  2017-10-31  02:14:11
# 4                         2018-08-07  ...  2018-07-30  03:24:27
#
#    product_category_name  product_name_lenght  product_description_lenght  \
# 0  utilidades_domesticas                 40.0                       268.0
# 1  utilidades_domesticas                 40.0                       268.0
# 2  utilidades_domesticas                 40.0                       268.0
# 3  utilidades_domesticas                 40.0                       268.0
# 4             perfumaria                 29.0                       178.0
#
#   product_photos_qty product_weight_g  product_length_cm  product_height_cm  \
# 0                4.0            500.0               19.0                8.0
# 1                4.0            500.0               19.0                8.0
# 2                4.0            500.0               19.0                8.0
# 3                4.0            500.0               19.0                8.0
# 4                1.0            400.0               19.0               13.0
#
#   product_width_cm
# 0             13.0
# 1             13.0
# 2             13.0
# 3             13.0
# 4             19.0
#
# [5 rows x 29 columns]

# %%
average_products_per_customer = merged_data.groupby('customer_id')['product_id'].count().mean()

# %%
print(f'A média de produtos comprados por cliente é: {average_products_per_customer:.2f}')
# Out:
# A média de produtos comprados por cliente é: 1.14
