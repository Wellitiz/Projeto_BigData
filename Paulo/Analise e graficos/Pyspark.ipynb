# %%
pip install pyspark
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
spark = SparkSession.builder.appName("NomeDoApp").getOrCreate()


product_category_name_translation = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/product_category_name_translation.csv', header=True)
t_olist_geolocation_dataset_1 = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/t_olist_geolocation_dataset-1.csv', header=True)
csv_olist_customers_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/csv_olist_customers_dataset.csv', header=True)
t_olist_orders_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/t_olist_orders_dataset.csv', header=True)
csv_olist_order_reviews_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/csv_olist_order_reviews_dataset.csv', header=True)
t_olist_order_payments_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/t_olist_order_payments_dataset.csv', header=True)
csv_olist_order_items_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/csv_olist_order_items_dataset.csv', header=True)
olist_products_dataset = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/olist_products_dataset.csv', header=True)
olist_sellers_dataset_cidade_tratado = spark.read.csv('C:/Users/ticam/OneDrive/Área de Trabalho/Projeto ifood/Projeto_BigData/Paulo/Dados analisados/olist_sellers_dataset_cidade_tratado.csv', header=True)

# %%
product_category_name_translation.show()
# Out:
# +---------------------+-----------------------------+
# |product_category_name|product_category_name_english|
# +---------------------+-----------------------------+
# |         beleza_saude|                health_beauty|
# | informatica_acess...|         computers_accesso...|
# |           automotivo|                         auto|
# |      cama_mesa_banho|               bed_bath_table|
# |     moveis_decoracao|              furniture_decor|
# |        esporte_lazer|               sports_leisure|
# |           perfumaria|                    perfumery|
# | utilidades_domest...|                   housewares|
# |            telefonia|                    telephony|
# |   relogios_presentes|                watches_gifts|
# |    alimentos_bebidas|                   food_drink|
# |                bebes|                         baby|
# |            papelaria|                   stationery|
# | tablets_impressao...|         tablets_printing_...|
# ...

# %%
orders_customers = t_olist_orders_dataset.join(csv_olist_customers_dataset, on='customer_id')
orders_reviews = orders_customers.join(csv_olist_order_reviews_dataset, on='order_id')
orders_payments = orders_reviews.join(t_olist_order_payments_dataset, on='order_id')
orders_items = orders_payments.join(csv_olist_order_items_dataset, on='order_id')
orders_products = orders_items.join(olist_products_dataset, on='product_id')
orders_sellers = orders_products.join(olist_sellers_dataset_cidade_tratado, on='seller_id')


orders_sellers.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+------------+-----------------------------+-----------------------------+----------------------+----------------------+---------------------------------+---------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+-----+--------------------+------------------------+--------------------+--------------+-----+--------------------+------------+--------------------+----------------------+--------------------+--------------------+------------------+------------------+------------------+------------+--------------------+-------------+---+-------------+------+-------------+----------+--------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+---------------+-----------
# ...

# %%
orders_sellers = orders_seller.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 orders_sellers = orders_seller.columns
#
# NameError: name 'orders_seller' is not defined
